# %% [markdown]
# <a href="https://colab.research.google.com/github/NoCodeProgram/deepLearning/blob/main/transformer/multiheadAttention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/NoCodeProgram/deepLearning.git
# Out:
# Cloning into 'deepLearning'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 254 (delta 42), reused 0 (delta 0), pack-reused 139
# Receiving objects: 100% (254/254), 12.36 MiB | 20.38 MiB/s, done.
# Resolving deltas: 100% (78/78), done.

# %%
import torch
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

# Read the text file
with open('deepLearning/transformer/shakespeare.txt', 'r') as file:
    text = file.read()

# Tokenize the text  (this is very simple tokenizer, in reality you would use a more advanced one)
tokenizer = get_tokenizer('basic_english')
tokens = tokenizer(text)
unique_tokens = set(tokens)

# %%
stoi = { s:i for i,s in enumerate(unique_tokens)}
itos = { i:s for i,s in enumerate(unique_tokens)}
print(stoi)
print(itos)

vocab_size = len(unique_tokens)
print(vocab_size)
# Out:
# {'filed': 0, 'which': 1, 'lacked': 2, 'pencil': 3, 'thyself': 4, 'prouder': 5, 'jade': 6, 'offend': 7, 'stand': 8, 'costs': 9, 'bankrupt': 10, 'large': 11, 'invoked': 12, 'fuel': 13, 'poets': 14, 'anew': 15, 'vexed': 16, 'riper': 17, 'were': 18, 'wanton': 19, 'their': 20, 'bequest': 21, 'grecian': 22, 'harmful': 23, 'dart': 24, 'elements': 25, 'region': 26, 'style': 27, 'cut': 28, '!': 29, 'desiring': 30, 'shifting': 31, 'sell': 32, 'enjoyer': 33, 'didst': 34, 'widowed': 35, 'judgement': 36, 'sharp': 37, 'conquered': 38, 'been': 39, 'alters': 40, 'linger': 41, 'sparkling': 42, 'beguiled': 43, 'esteemed': 44, 'twilight': 45, 'press': 46, 'slow': 47, 'assistance': 48, 'redeem': 49, 'strikes': 50, 'issue': 51, 'word': 52, 'tombs': 53, 'thou': 54, 'slain': 55, 'would': 56, 'wherein': 57, 'wake': 58, 'wing': 59, 'cheek': 60, 'fulness': 61, 'enjoyed': 62, 'countenance': 63, 'throned': 64, 'may': 65, 'distills': 66, 'love-suit': 67, 'esteem': 68, 'inconstant': 69, 'walks': 70, 'asked': 71, 'feeding': 72, 'boughs': 73, 'flattered': 74, 'betwixt': 75, 'sequent': 76, 'travelled': 77, 'wear': 78, 'bearer': 79, 'runs': 80, 'inferior': 81, 'smells': 82, 'line': 83, 'much': 84, 'silence': 85, 'victor': 86, 'proud-pied': 87, 'quill': 88, 'puts': 89, 'painful': 90, 'unseeing': 91, 'admiring': 92, 'new-appearing': 93, 'small': 94, 'survey': 95, 'bliss': 96, 'stop': 97, 'brave': 98, 'purest': 99, 'travel': 100, 'sullen': 101, 'particulars': 102, 'sportive': 103, 'woeful': 104, 'gift': 105, 'sadly': 106, 'rich': 107, 'since': 108, 'end': 109, 'fashion': 110, 'term': 111, 'ne': 112, 'although': 113, 'dig': 114, 'decease': 115, 'wary': 116, 'mistaking': 117, 'fearing': 118, 'did': 119, 'half': 120, 'benefit': 121, 'constant': 122, 'process': 123, 'graciously': 124, 'new-found': 125, 'husbandry': 126, 'forget': 127, 'curious': 128, 'weep': 129, 'signs': 130, 'sympathized': 131, 'o': 132, 'petty': 133, 'so': 134, 'riot': 135, 'suited': 136, 'death': 137, 'graves': 138, 'feast': 139, 'goddess': 140, 'esteeming': 141, 'turned': 142, 'wardrobe': 143, 'rud': 144, 'star': 145, 'shoot': 146, 'suffers': 147, 'marble': 148, 'joy': 149, 'tall': 150, 'absence': 151, 'oft': 152, 'receive': 153, 'simply': 154, 'blenches': 155, 'executor': 156, 'elder': 157, 'revolt': 158, 'proudly': 159, 'as': 160, 'force': 161, 'outright': 162, 'bower': 163, 'share': 164, 'life': 165, 'muses': 166, 'act': 167, 'goodness': 168, 'mightier': 169, 'april': 170, 'none': 171, 'hoisted': 172, 'user': 173, 'great': 174, 'advocate': 175, 'metre': 176, 'snow': 177, 'foot': 178, 'abide': 179, 'check': 180, 'walls': 181, 'where-through': 182, 'neglect': 183, 'fury': 184, 'cry': 185, 'import': 186, 'impression': 187, 'stores': 188, 'duteous': 189, 'creatures': 190, 'to-day': 191, 'deserv': 192, 'way': 193, 'contents': 194, 'enrich': 195, 'engrafted': 196, 'bitterness': 197, 'frailties': 198, 'thy': 199, 'impute': 200, 'mouths': 201, 'stirred': 202, 'changes': 203, 'bough': 204, 'wind': 205, 'blessings': 206, 'shines': 207, 'breath': 208, 'admire': 209, 'wilful': 210, 'hied': 211, 'spent': 212, 'tell': 213, 'steal': 214, 'paper': 215, 'perhaps': 216, 'lying': 217, 'privilege': 218, 'beseechers': 219, 'on': 220, 'writers': 221, 'satire': 222, 'farthest': 223, 'waiting': 224, 'it': 225, 'takes': 226, 'same': 227, 'pattern': 228, 'guest': 229, 'king': 230, 'torture': 231, 'shore': 232, 'devouring': 233, 'fester': 234, 'breast': 235, 'vantage': 236, 'food': 237, 'fled': 238, 'enough': 239, 'pitch': 240, 'present': 241, 'compile': 242, 'teeming': 243, 'nerves': 244, 'dancing': 245, 'sun': 246, 'return': 247, 'wood': 248, 'run': 249, 'trust': 250, 'dross': 251, 'change': 252, 'fresher': 253, 'profound': 254, 'directly': 255, 'unlettered': 256, 'meadows': 257, 'trifles': 258, 'stays': 259, 'gentlest': 260, 'duty': 261, 'shallowest': 262, 'says': 263, 'autumn': 264, 'hymns': 265, 'extern': 266, 'lily': 267, 'defect': 268, 'mayst': 269, 'proving': 270, 'commits': 271, 'deserving': 272, 'jewels': 273 ...
# {0: 'filed', 1: 'which', 2: 'lacked', 3: 'pencil', 4: 'thyself', 5: 'prouder', 6: 'jade', 7: 'offend', 8: 'stand', 9: 'costs', 10: 'bankrupt', 11: 'large', 12: 'invoked', 13: 'fuel', 14: 'poets', 15: 'anew', 16: 'vexed', 17: 'riper', 18: 'were', 19: 'wanton', 20: 'their', 21: 'bequest', 22: 'grecian', 23: 'harmful', 24: 'dart', 25: 'elements', 26: 'region', 27: 'style', 28: 'cut', 29: '!', 30: 'desiring', 31: 'shifting', 32: 'sell', 33: 'enjoyer', 34: 'didst', 35: 'widowed', 36: 'judgement', 37: 'sharp', 38: 'conquered', 39: 'been', 40: 'alters', 41: 'linger', 42: 'sparkling', 43: 'beguiled', 44: 'esteemed', 45: 'twilight', 46: 'press', 47: 'slow', 48: 'assistance', 49: 'redeem', 50: 'strikes', 51: 'issue', 52: 'word', 53: 'tombs', 54: 'thou', 55: 'slain', 56: 'would', 57: 'wherein', 58: 'wake', 59: 'wing', 60: 'cheek', 61: 'fulness', 62: 'enjoyed', 63: 'countenance', 64: 'throned', 65: 'may', 66: 'distills', 67: 'love-suit', 68: 'esteem', 69: 'inconstant', 70: 'walks', 71: 'asked', 72: 'feeding', 73: 'boughs', 74: 'flattered', 75: 'betwixt', 76: 'sequent', 77: 'travelled', 78: 'wear', 79: 'bearer', 80: 'runs', 81: 'inferior', 82: 'smells', 83: 'line', 84: 'much', 85: 'silence', 86: 'victor', 87: 'proud-pied', 88: 'quill', 89: 'puts', 90: 'painful', 91: 'unseeing', 92: 'admiring', 93: 'new-appearing', 94: 'small', 95: 'survey', 96: 'bliss', 97: 'stop', 98: 'brave', 99: 'purest', 100: 'travel', 101: 'sullen', 102: 'particulars', 103: 'sportive', 104: 'woeful', 105: 'gift', 106: 'sadly', 107: 'rich', 108: 'since', 109: 'end', 110: 'fashion', 111: 'term', 112: 'ne', 113: 'although', 114: 'dig', 115: 'decease', 116: 'wary', 117: 'mistaking', 118: 'fearing', 119: 'did', 120: 'half', 121: 'benefit', 122: 'constant', 123: 'process', 124: 'graciously', 125: 'new-found', 126: 'husbandry', 127: 'forget', 128: 'curious', 129: 'weep', 130: 'signs', 131: 'sympathized', 132: 'o', 133: 'petty', 134: 'so', 135: 'riot', 136: 'suited', 137: 'death', 138: 'graves', 139: 'feast', 140: 'goddess', 141: 'esteeming', 142: 'turned', 143: 'wardrobe', 144: 'rud', 145: 'star', 146: 'shoot', 147: 'suffers', 148: 'marble', 149: 'joy', 150: 'tall', 151: 'absence', 152: 'oft', 153: 'receive', 154: 'simply', 155: 'blenches', 156: 'executor', 157: 'elder', 158: 'revolt', 159: 'proudly', 160: 'as', 161: 'force', 162: 'outright', 163: 'bower', 164: 'share', 165: 'life', 166: 'muses', 167: 'act', 168: 'goodness', 169: 'mightier', 170: 'april', 171: 'none', 172: 'hoisted', 173: 'user', 174: 'great', 175: 'advocate', 176: 'metre', 177: 'snow', 178: 'foot', 179: 'abide', 180: 'check', 181: 'walls', 182: 'where-through', 183: 'neglect', 184: 'fury', 185: 'cry', 186: 'import', 187: 'impression', 188: 'stores', 189: 'duteous', 190: 'creatures', 191: 'to-day', 192: 'deserv', 193: 'way', 194: 'contents', 195: 'enrich', 196: 'engrafted', 197: 'bitterness', 198: 'frailties', 199: 'thy', 200: 'impute', 201: 'mouths', 202: 'stirred', 203: 'changes', 204: 'bough', 205: 'wind', 206: 'blessings', 207: 'shines', 208: 'breath', 209: 'admire', 210: 'wilful', 211: 'hied', 212: 'spent', 213: 'tell', 214: 'steal', 215: 'paper', 216: 'perhaps', 217: 'lying', 218: 'privilege', 219: 'beseechers', 220: 'on', 221: 'writers', 222: 'satire', 223: 'farthest', 224: 'waiting', 225: 'it', 226: 'takes', 227: 'same', 228: 'pattern', 229: 'guest', 230: 'king', 231: 'torture', 232: 'shore', 233: 'devouring', 234: 'fester', 235: 'breast', 236: 'vantage', 237: 'food', 238: 'fled', 239: 'enough', 240: 'pitch', 241: 'present', 242: 'compile', 243: 'teeming', 244: 'nerves', 245: 'dancing', 246: 'sun', 247: 'return', 248: 'wood', 249: 'run', 250: 'trust', 251: 'dross', 252: 'change', 253: 'fresher', 254: 'profound', 255: 'directly', 256: 'unlettered', 257: 'meadows', 258: 'trifles', 259: 'stays', 260: 'gentlest', 261: 'duty', 262: 'shallowest', 263: 'says', 264: 'autumn', 265: 'hymns', 266: 'extern', 267: 'lily', 268: 'defect', 269: 'mayst', 270: 'proving', 271: 'commits', 272: 'deserving', 273: 'jewels' ...
# 3129

# %%
sentence = "i love you all"
indices = [stoi[word] for word in sentence.split()]
print(indices)

import torch.nn as nn

embedding_dim = 20
embedding = nn.Embedding(vocab_size, embedding_dim)

embedded_sentence = embedding(torch.tensor(indices))
print(embedded_sentence)
# Out:
# [1400, 658, 321, 2661]
# tensor([[ 0.0925,  0.0993, -0.2679, -0.2897,  0.6791, -1.3325, -1.4117, -0.9931,
#          -0.2453, -0.3506,  1.8642,  0.6862, -0.7704, -0.1396, -1.7060,  1.4248,
#           1.4760, -0.6616, -0.3940,  1.2568],
#         [ 0.4818, -1.4555,  0.0211, -1.7342,  0.1788, -0.0343, -0.7334,  0.3300,
#          -0.7932, -1.3668,  0.3013,  0.5729, -0.9761,  0.6527,  0.1741, -0.1306,
#          -0.4450,  2.0865, -0.5614, -1.0796],
#         [-0.2783, -0.8294, -0.0323, -0.1246,  0.6529,  0.6033, -0.1477, -0.2540,
#           1.6059,  1.4985, -0.4159,  0.5053, -0.4023, -0.3188, -0.3874, -1.4405,
#          -1.8073, -0.6821,  0.0633, -0.1453],
#         [-0.0342, -0.1321,  0.2908,  1.5125,  1.0318, -0.5913,  0.1666, -0.5430,
#          -0.5951, -0.6156,  0.9003, -0.0048,  1.9140, -0.8457, -2.3570, -0.3435,
#           2.4975, -1.0575,  0.2997, -0.4541]], grad_fn=<EmbeddingBackward0>)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SelfAttention(nn.Module):
    def __init__(self, embed_dim, atten_dim):
        super().__init__()
        self.query = nn.Linear(embed_dim, atten_dim, bias=False)
        self.key = nn.Linear(embed_dim, atten_dim, bias=False)
        self.value = nn.Linear(embed_dim, atten_dim, bias=False)

    def forward(self, x):
        query = self.query(x)
        key = self.key(x)
        value = self.value(x)

        scores = torch.matmul(query, key.transpose(-2, -1))
        scores = scores / key.size(-1)**0.5

        attention_weights = F.softmax(scores, dim=-1)
        weighted_values = torch.matmul(attention_weights, value)

        return weighted_values

# %%
class MultiheadAttention(nn.Module):
    def __init__(self, embed_dim, num_heads):
        super().__init__()
        attention_dim = embed_dim // num_heads
        self.attentions = nn.ModuleList([SelfAttention(embed_dim, attention_dim) for _ in range(num_heads)])
        self.fc = nn.Linear(embed_dim, embed_dim)

    def forward(self, x):
        head_outputs = []
        for attention in self.attentions:
            head_output = attention(x)
            head_outputs.append(head_output)

        concatenated_heads = torch.cat(head_outputs, dim=-1)
        print("concatenated_heads", concatenated_heads.shape)
        output = self.fc(concatenated_heads)
        print("output", output.shape)
        return output

# %%
num_heads = 4

output = MultiheadAttention(embedding_dim, num_heads)(embedded_sentence)
print("output shape", output.shape)
# Out:
# concatenated_heads torch.Size([4, 20])
# output torch.Size([4, 20])
# output shape torch.Size([4, 20])
